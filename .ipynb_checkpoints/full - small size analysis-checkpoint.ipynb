# %%
import pandas as pd 
import pickle
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import tensorflow as tf
import xgboost as xgb
from tensorflow.keras.layers import LSTM

from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim

from torch.optim.swa_utils import AveragedModel, SWALR
from torch.optim.lr_scheduler import CosineAnnealingLR


import random

# %%
data = []
with (open("saved_results/clients_data_full", "rb")) as openfile:
    while True:
        try:
            data.append(pickle.load(openfile))
        except EOFError:
            break

# %%
filename_env = "../PV V2/Synthetic_PV_profiles/saved_results/PV_UniModal_nicolas_env_raw_150"

file = open(filename_env, 'rb') 
env_dict = pickle.load(file) 
msg = '[INFO] loaded data for {:2.0f} clients'.format(env_dict['num_clients'])

print(msg)
# Out:
# [INFO] loaded data for 24 clients

# %%
clients_data = env_dict['train_scenarios']['sml']['clients_data']

# %%
for m in range(len(clients_data)): 
    print("Client " + str(m))
    client_1 = clients_data[m]    

    mat_train = np.matrix(client_1[0])
    clients = pd.DataFrame(mat_train)

    y = [client_1[1][i].item() for i in range(len(client_1[1]))]

    clients['y'] = y

    print(len(clients))
    
    mat_test = np.matrix(client_1[2])
    test = pd.DataFrame(mat_test)

    y = [client_1[3][i].item() for i in range(len(client_1[3]))]

    test['y'] = y
# Out:
# Client 0
# 150
# Client 1
# 150
# Client 2
# 150
# Client 3
# 150
# Client 4
# 150
# Client 5
# 150
# Client 6
# 150
# Client 7
# 150
# Client 8
# 150
# Client 9
# 150
# Client 10
# 150
# Client 11
# 150
# Client 12
# 150
# Client 13
# 150
# Client 14
# 150
# Client 15
# 150
# Client 16
# 150
# Client 17
# 150
# Client 18
# 150
# Client 19
# 150
# Client 20
# 150
# Client 21
# 150
# Client 22
# 150
# Client 23
# 150

# %%
#One dataframe per household
dfs_train = [None]*25
dfs_test = [None]*25
dfs_big = [None]*25
means = [None]*25
stds = [None]*25

for i in range(len(data[0])):
    #Create train dfs
    mat_train = np.matrix(data[0][i][0])
    dfs_train[i] = pd.DataFrame(mat_train)
    dfs_train[i].drop(7, axis = 1, inplace = True)
    dfs_train[i]['pred'] = data[0][i][1].tolist()
    
    #Create test dfs
    mat = np.matrix(data[0][i][2])
    dfs_test[i] = pd.DataFrame(mat)
    dfs_test[i].drop(7, axis = 1, inplace = True)
    dfs_test[i]['pred'] = data[0][i][3].tolist()
    
    dfs_big[i] = dfs_train[i].append(dfs_test[i])
    #dfs_big[i] = (dfs_big[i]-dfs_big[i].mean())/dfs_big[i].std()

# %%
len(dfs_big[1])
# Out:
# 608

# %% [markdown]
# ## Linear model on big dataset

# %%
#One model per household
r_2 = [None]*len(dfs_train)
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):
    X = dfs_big[i].loc[:, dfs_big[i].columns != 'pred']


    y = dfs_big[i].loc[:, dfs_big[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)
    
    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)
    
    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t
    
    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    
    
    regr = linear_model.LinearRegression()
    regr.fit(X_train, y_train)

    y_pred = regr.predict(X_test)
    

    
    y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
    y_test = y_test*std_y_t+mean_y_t 
    
    
    r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
    mserror[i] = mean_squared_error(y_test, y_pred)
    
    
r2_adj = np.mean(r_2)
std = (np.std(r_2)/r2_adj)*100
mse = np.mean(mserror)

print("Adjusted R2 : " + r2_adj.astype(str) + "\nMSE : " + mse.astype(str) + " +- " + std.astype(str) + "%")
# Out:
# Adjusted R2 : 0.7260501387246925
# MSE : 523.8062721744604 +- 6.770246645894347%

# %%
mserror
# Out:
# [402.5049379922423,
#  711.5602070864624,
#  661.1193768430277,
#  541.2046462134304,
#  660.6205789056839,
#  714.2149891673121,
#  483.4841551568452,
#  447.1345631436109,
#  582.5508341598213,
#  556.4049291180875,
#  244.3785903170049,
#  432.95871245475456,
#  402.57991509642073,
#  585.7074978944946,
#  666.5382068864657,
#  326.2871483620899,
#  710.3833948794127,
#  610.6705111449429,
#  218.4734901445108,
#  598.7837909152161,
#  597.7273195007681,
#  528.2789097267175,
#  582.8797652283242,
#  180.95494422633152,
#  647.7553897975341]

# %% [markdown]
# ## Linear model on varying dataset size

# %%
step = 10

#One model per household
r_2 = [None]*len(dfs_train)
mserror = [None]*len(dfs_train)
dfs_bigs = [None]*len(dfs_big)
r2_adj = [None]*len(range(30, len(dfs_big[1]), step))
mse_lin = [None]*len(range(30, len(dfs_big[1]), step))

j = 0
for n in range(30, len(dfs_big[1]), step):
    for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(n, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t

        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)

        y_pred = regr.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
    

        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred, squared = False)

    #r2_adj[j] = np.mean(r_2)
    mse_lin[j] = np.mean(mserror)
    j += 1

plt.figure()
plt.plot(list(range(30, len(dfs_big[1]), step)), mse_lin)

# %% [markdown]
# ## XGBoost on big dataset

# %%
#One model per household
r_2 = [None]*len(dfs_train)
mserror = [None]*len(dfs_train)
std = [None]*len(dfs_train)


for i in range(len(dfs_train)):
    X = dfs_big[i].loc[:, dfs_big[i].columns != 'pred']


    y = dfs_big[i].loc[:, dfs_big[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
        
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)
    
    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)
    
    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t
    
    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    

    xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                    max_depth = 4, alpha = 4, n_estimators = 300)

    xg_reg.fit(X_train, y_train)
    y_pred = xg_reg.predict(X_test)


    y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
    y_test = y_test*std_y_t+mean_y_t 
    
    r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
    mserror[i] = np.sqrt(mean_squared_error(y_test, y_pred))
    
    
r2_adj = np.mean(r_2)
std = (np.std(r_2)/r2_adj)*100
mse = np.mean(mserror)

print("Adjusted R2 : " + r2_adj.astype(str) + "\nMSE : " + mse.astype(str) + " +- " + std.astype(str) + "%")
# Out:
# Adjusted R2 : 0.6580737822121782
# MSE : 24.19245136034157 +- 21.201597770942644%

# %% [markdown]
# ## XGBoost on varying dataset size

# %%
step = 10

#One model per household
r_2 = [None]*len(dfs_train)
mserror = [None]*len(dfs_train)
dfs_bigs = [None]*len(dfs_big)
r2_adj = [None]*len(range(30, len(dfs_big[1]), step))
mse = [None]*len(range(30, len(dfs_big[1]), step))

j = 0
for n in range(30, len(dfs_big[1]), step):
    for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(n, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

    
        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t

        
        xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                        max_depth = 4, alpha = 4, n_estimators = 300)

        xg_reg.fit(X_train, y_train)
        y_pred = xg_reg.predict(X_test)


        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred, squared = False)

    #r2_adj[j] = np.mean(r_2)
    mse[j] = np.mean(mserror)
    j += 1

plt.figure()
plt.plot(list(range(30, len(dfs_big[1]), step)), mse)

# %%
plt.figure()
plt.title("RMSE evolution for different dataset sizes")
plt.xlabel("Dataset size (rows)")
plt.ylabel("RMSE")
plt.plot(list(range(30, len(dfs_big[1]), step)), mse,label = "XGBoost")
plt.plot(list(range(30, len(dfs_big[1]), step)), mse_lin, label = "Linear Model")
plt.legend()

# %% [markdown]
# The knee is at approx 150

# %% [markdown]
# ### Get the values N = 150

# %%
plt.figure(figsize = (20,10))
plt.plot(range(len(y_test)), y_test, color = "grey", linestyle = "dashed", label = "Reference value")
plt.plot(y_pred, label = "Linear model")
plt.plot(y_pred_xg, label = "XGBoost")

plt.legend()
plt.xlabel("Time (h)", size = 15)
plt.ylabel("Production potential (kW)", size = 15) 
#plt.title("Predicted values against reference values for linear regression and XGBoost")
# Out:
# Text(0, 0.5, 'Production potential (kW)')

# %%
dfs_bigs = dfs_big[10].sample(150, replace = True, random_state=1)

X = dfs_bigs.loc[:, dfs_bigs.columns != 'pred']


y = dfs_bigs.loc[:, dfs_bigs.columns == 'pred']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

mean_x_t = np.mean(X_train)
std_x_t =  np.std(X_train)

mean_y_t = np.mean(y_train)
std_y_t =  np.std(y_train)

X_train = (X_train-mean_x_t)/std_x_t
y_train = (y_train-mean_y_t)/std_y_t

X_test = (X_test-mean_x_t)/std_x_t
y_test = (y_test-mean_y_t)/std_y_t


xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 4, alpha = 4, n_estimators = 300)

xg_reg.fit(X_train, y_train)
y_pred_xg_150 = xg_reg.predict(X_test)

#y_test_xg_150 = y_test*std_y_t+mean_y_t 


#y_pred_xg_150 = [x.item()*std_y_t+mean_y_t for x in y_pred]

# %%
dfs_bigs = dfs_big[10]

X = dfs_bigs.loc[:, dfs_bigs.columns != 'pred']


y = dfs_bigs.loc[:, dfs_bigs.columns == 'pred']

X_train, X_test_x, y_train, y_test_x = train_test_split(X, y, test_size=0.20, random_state=42)

mean_x_t = np.mean(X_train)
std_x_t =  np.std(X_train)

mean_y_t = np.mean(y_train)
std_y_t =  np.std(y_train)

X_train = (X_train-mean_x_t)/std_x_t
y_train = (y_train-mean_y_t)/std_y_t

X_test_x = (X_test_x-mean_x_t)/std_x_t
y_test_x = (y_test_x-mean_y_t)/std_y_t


xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 4, alpha = 4, n_estimators = 300)

xg_reg.fit(X_train, y_train)


y_pred_xg_tot = xg_reg.predict(X_test)


#y_pred_xg_tot = [x.item()*std_y_t+mean_y_t for x in y_pred]

# %%
plt.figure(figsize = (20,10))
plt.plot(range(len(y_test)), y_test, color = "grey", linestyle = "dashed", label = "Reference value")
plt.plot(y_pred_xg_150, label = "N = 150")
plt.plot(y_pred_xg_tot, label = "N = 610")

plt.legend()
plt.xlabel("Time (h)", size = 15)
plt.ylabel("Production potential (kW)", size = 15) 
#plt.title("Predicted values against reference values for linear regression and XGBoost")
# Out:
# Text(0, 0.5, 'Production potential (kW)')

# %%
dfs_bigs = [None]*len(dfs_big)
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(150, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t

        
        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)

        y_pred = regr.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred, squared = False)
        #print(i)
        #print(mserror[i])

print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)/np.mean(mserror)*100))
# Out:
# 24.033172652922218 +- 23.781568247536498

# %%
mserror = [None]*len(dfs_train)
dfs_bigs = [None]*len(dfs_big)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(605, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t


        xg_reg_600 = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                        max_depth = 4, alpha = 4, n_estimators = 300)

        xg_reg_600.fit(X_train, y_train)
        y_pred = xg_reg_600.predict(X_test)


        y_pred_xg = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred_xg, squared = False)
        print(i)
        print(mserror[i])
        
print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)/np.mean(mserror)*100))
# Out:
# 0
# 22.228991759489137
# 1
# 22.186037957723247
# 2
# 21.52813471201562
# 3
# 13.995460705751462
# 4
# 18.99112896903978
# 5
# 18.22876332529604
# 6
# 21.79773521020178
# 7
# 20.891049467253662
# 8
# 20.449883205119313
# 9
# 21.082116862826304
# 10
# 21.606924563157285
# 11
# 20.550480877649754
# 12
# 19.60706465983548
# 13
# 10.16822812337916
# 14
# 19.67901639552293
# 15
# 20.551687898244626
# 16
# 21.080419118756026
# 17
# 19.841615864538955
# 18
# 22.089592841195806
# 19
# 16.730174296493797
# 20
# 21.81372835817956
# 21
# 22.335516893841028
# 22
# 19.652763160780342
# 23
# 18.07011982002798
# 24
# 15.247232739857237
# 19.616154711447052 +- 14.61745546583256

# %%
xg_reg_150 = xg_reg

# %%
X_test_plot = X_test
y_test_plot = y_test

# %%
y_pred_600 = xg_reg_600.predict(X_test_plot)
y_pred_150 = xg_reg_150.predict(X_test_plot)

mean_y_t = np.mean(y_test_plot)
std_y_t =  np.std(y_test_plot)

y_pred_600 = [x.item()*std_y_t+mean_y_t for x in y_pred_600]
y_pred_150 = [x.item()*std_y_t+mean_y_t for x in y_pred_150]

# %%
y_pred_600
# Out:
# array([-0.4813545 ,  0.07620249, -0.312508  ,  0.15044647, -0.48030496,
#        -0.8471639 ,  0.9804848 , -0.64280915,  0.59272414,  1.9699783 ,
#        -0.32028955,  0.16422483, -0.32044184,  0.587757  ,  1.7816749 ,
#         0.48554727,  0.21569036,  0.51153857,  0.30017638, -0.09156743,
#        -0.40332663,  0.2031982 , -0.6292237 ,  0.54919285,  1.3103082 ,
#         1.0108132 ,  0.4527472 ,  0.47572097, -0.28319055,  0.30802315],
#       dtype=float32)

# %%
y_pred_150
# Out:
# array([-0.19288152, -0.20910901,  0.29001066,  0.6440902 , -0.7558445 ,
#        -1.0993546 ,  0.93321526, -1.089065  , -0.19859673,  1.2172929 ,
#         0.09989886, -0.2569061 , -0.4335399 , -0.12337591,  1.2205195 ,
#         0.2700067 ,  0.04087128,  0.2072436 ,  0.6012048 ,  0.14360194,
#        -0.6956832 ,  0.11019817, -1.0631821 , -0.12209606,  1.4639026 ,
#         1.0568103 ,  0.07270354,  1.2968203 , -0.39956778,  0.46369287],
#       dtype=float32)

# %%
x = list(range(11,16)) + list(range(11,16)) + list(range(11,16)) + list(range(11,16)) + list(range(11,16))+ list(range(11,16))
x = x+x
y = list(range(0,60))
plt.figure(figsize = (20,10))
plt.plot(range(len(y_test[0:60])), y_test[0:60], color = "red", label = "Reference value", linewidth = "2")
plt.plot(y_pred_150[0:60], label = "N = 150", color = "y")
plt.plot(y_pred_600[0:60], label = "N = 610" )

plt.xticks(y,x)
plt.legend(prop={'size': 15})
plt.xlabel("Time (h)", size = 15)
plt.ylabel("Production potential (kW)", size = 15) 
#plt.title("Predicted values against reference values for linear regression and XGBoost")
# Out:
# Text(0, 0.5, 'Production potential (kW)')

# %%
#One model per household
r_2 = [None]*len(dfs_train)
mserror = [None]*len(dfs_train)

for i in range(len(dfs_train)):
    
    dfs_bigs[i] = dfs_big[i].sample(155, replace = True, random_state=1)
        
    X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


    y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)
    
    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)
    
    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t
    
    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    

    #Initialising ANN
    ann = tf.keras.models.Sequential()

    #Adding First Hidden Layer
    ann.add(tf.keras.layers.Dense(units=8, activation = "relu"))

    #Adding Second Hidden Layer
    ann.add(tf.keras.layers.Dense(units=4))

    #Adding Output Layer
    ann.add(tf.keras.layers.Dense(units=1))

    
    
    #Compiling ANN
    ann.compile(optimizer="adam",loss="MeanSquaredError")
    
    #Fitting ANN
    ann.fit(X_train,y_train,batch_size=32,epochs = 100, verbose=0)

    y_pred = ann.predict(X_test)
    
    y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
    y_test = y_test*std_y_t+mean_y_t 
    
    
    r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
    mserror[i] = mean_squared_error(y_test, y_pred, squared = False)
    
    

mse = np.mean(mserror)
std = (np.std(mserror)/mse)*100

print("\nMSE : " + mse.astype(str) + "+- " + std.astype(str) + "%")
# Out:
# ...
# 1/1 [==============================] - 1s 670ms/step
#
# MSE : 25.62818018509686+- 17.75086844946598%

# %% [markdown]
# ### Get the values N = 100

# %%
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(100, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t


        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)

        y_pred = regr.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred)

print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)))
# Out:
# 1112.7440257126375 +- 439.15430782637424

# %%
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(100, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t


        xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                        max_depth = 4, alpha = 4, n_estimators = 300)

        xg_reg.fit(X_train, y_train)
        y_pred = xg_reg.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred)
        
print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)))
# Out:
# 982.0112277946589 +- 349.6684649332471

# %% [markdown]
# ### Values for N=50

# %%
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(40, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t


        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)

        y_pred = regr.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred)

print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)))
# Out:
# 712.166252443307 +- 312.2436502374113

# %%
mserror = [None]*len(dfs_train)
for i in range(len(dfs_train)):

        dfs_bigs[i] = dfs_big[i].sample(40, replace = True, random_state=1)
        
        X = dfs_bigs[i].loc[:, dfs_bigs[i].columns != 'pred']


        y = dfs_bigs[i].loc[:, dfs_bigs[i].columns == 'pred']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

        mean_x_t = np.mean(X_train)
        std_x_t =  np.std(X_train)

        mean_y_t = np.mean(y_train)
        std_y_t =  np.std(y_train)

        X_train = (X_train-mean_x_t)/std_x_t
        y_train = (y_train-mean_y_t)/std_y_t

        X_test = (X_test-mean_x_t)/std_x_t
        y_test = (y_test-mean_y_t)/std_y_t


        xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                        max_depth = 4, alpha = 4, n_estimators = 300)

        xg_reg.fit(X_train, y_train)
        y_pred = xg_reg.predict(X_test)

        y_pred = [x.item()*std_y_t+mean_y_t for x in y_pred]
        y_test = y_test*std_y_t+mean_y_t 
        
        #r_2[i] = 1-(1-r2_score(y_test, y_pred))*((len(X_test)-1)/(len(X_test)-len(X_test.columns)-1))
        mserror[i] = mean_squared_error(y_test, y_pred)
        
print(str(np.mean(mserror)) + " +- " + str(np.std(mserror)))
# Out:
# 721.2448337444843 +- 267.69767187966045

# %% [markdown]
# ## Pytorch FedAvg

# %% [markdown]
# ### N = 50

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 50)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t

    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_model, loss_150, loss_150_t, hist = fed_sgd(data, testing, iterations, N, S, n_feat)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_model(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 713.48157 +- 364.57172

# %% [markdown]
# ### For N = 150

# %%
data = []
test = []


for i in range(len(clients_data)):
    
    client_1 = clients_data[i]    

    mat_train = np.matrix(client_1[0])
    clients = pd.DataFrame(mat_train)

    y = pd.Series([client_1[1][i].item() for i in range(len(client_1[1]))])

    clients['y'] = y
    
    mat_test = np.matrix(client_1[2])
    testi = pd.DataFrame(mat_test)

    y = pd.Series([client_1[3][i].item() for i in range(len(client_1[3]))])

    testi['y'] = y
    
    X_train = clients[list(range(0,9))]
    y_train = clients["y"]
    
    
    X_test = testi[list(range(0,9))]
    y_test = testi["y"]

    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t

    data.append((X_train.to_numpy(),y_train.to_numpy()))
    
    test.append((X_test.to_numpy(),y_test.to_numpy()))
    

N = len(clients_data)
iterations = 5000
S = 20
n_feat = 9

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_model, loss_150, loss_150_t, hist = fed_sgd(data, testing, iterations, N, S, n_feat)

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 150)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t

    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_model, loss_150, loss_150_t, hist = fed_sgd(data, testing, iterations, N, S, n_feat)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_model(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = np.sqrt(mses[i].detach().numpy())

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)/np.mean(mses)*100))
# Out:
# 33.336952 +- 1.197202131152153

# %%
for i in range(0,13):
    al = np.stack(hist, axis=0)[:,0][:,i]
    plt.figure()
    plt.plot(range(0,len(al)), np.abs(al))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15852/729125119.py in <module>
#       1 for i in range(0,13):
# ----> 2     al = np.stack(hist, axis=0)[:,0][:,i]
#       3     plt.figure()
#       4     plt.plot(range(0,len(al)), np.abs(al))
#
# IndexError: index 9 is out of bounds for axis 1 with size 9

# %% [markdown]
# ### For N = 100

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 100)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t

    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_model, loss_100, loss_100_t, hist = fed_sgd(data, testing, iterations, N, S, n_feat)

# %%
a = [np.mean(loss_100[i]) for i in range(len(loss_100))]
b = [np.mean(loss_100_t[i]) for i in range(len(loss_100_t))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.legend()

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_model(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 685.06 +- 356.0206

# %%
for i in range(0,13):
    al = np.stack(hist, axis=0)[:,0][:,i]
    plt.figure()
    plt.plot(range(0,len(al)), np.abs(al))

# %% [markdown]
# ## The Fed SGD function

# %%
def fed_sgd(data, test, iterations, N, S, n_feat):
    
    grad_mean_hist = []
    
    #Definition of the server model
    model_server = nn.Linear(n_feat, 1)
    optimizer_server = optim.Adam(model_server.parameters())
    loss_fn = nn.MSELoss()


    #One model per clients
    models = [None]*N
    opti = [None]*N
    loss_fct = [None]*N

    for i in range(len(models)):
        models[i] = nn.Linear(n_feat, 1)
        opti[i] = optim.Adam(models[i].parameters())
        loss_fct[i] = nn.MSELoss()

    mse = []
    mse_test = []
    #Iterations
    for i in range(0,iterations):

        #Random selection of clients
        a = list(range(0,N))
        sel = random.sample(a,S)

        grad = []
        bias = []
        loc = 0

        loss = [None]*S
        loss_test = [None]*S
        losses = 0

        #Clients iteration
        for j in sel:
            opti[loc].zero_grad()
            models[loc].weight = model_server.weight
            models[loc].weight.grad = None
            models[loc].bias = model_server.bias
            models[loc].bias.grad = None

            predictions = models[loc](data[j][0])
            loss[loc] = loss_fct[loc](predictions, data[j][1])
            loss[loc].backward()
            
            pred_test = models[loc](test[j][0])
            loss_test[loc] = loss_fct[loc](pred_test, test[j][1])

            loss[loc] = loss[loc].item()
            loss_test[loc] = loss_test[loc].item()
            
            grad.append(models[loc].weight.grad.numpy())
            bias.append(models[loc].bias.grad.numpy())
            loc+=1
            
        mse.append((loss))    
        mse_test.append((loss_test))
        
        grad = np.stack(grad, axis=0)
        grad_mean = torch.FloatTensor(grad.mean(axis = 0))
        
        grad_mean_hist.append(grad_mean)
        

        bias_mean = torch.FloatTensor([np.mean(bias)])
        model_server.weight.grad = grad_mean
        model_server.bias.grad = bias_mean
        optimizer_server.step()
        torch.nn.utils.clip_grad_norm_(parameters=model_server.parameters(), max_norm=10, norm_type=2.0)
    return model_server, mse, mse_test, grad_mean_hist

# %% [markdown]
# ## Federated SGD with Neural Network

# %% [markdown]
# ### N = 50

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 50)
    
    
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 877.64056 +- 581.0254

# %%
a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for N = 50')
plt.legend()

# %% [markdown]
# ### N = 150

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 150)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 10000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))


for i in range(len(mses)):
    mses[i] = np.sqrt(mses[i].detach().numpy())

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)/np.mean(mses)*100))
# Out:
# 19.542387 +- 19.16755735874176

# %% [markdown]
# ### For N = 500

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 500)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 436.31143 +- 199.32024

# %% [markdown]
# ### Test sigmoid

# %% [markdown]
# Relu with N = 500

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 500)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim)
# Out:
# NeuralNetwork(
#   (layer_1): Linear(in_features=13, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 442.08426 +- 140.34595

# %% [markdown]
# Sigmoid with N = 500

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 500)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "sigmoid")
# Out:
# NeuralNetwork(
#   (layer_1): Linear(in_features=13, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 445.8695 +- 171.13089

# %% [markdown]
# Sigmoid with N = 150

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 150)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "sigmoid")

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))


for i in range(len(mses)):
    mses[i] = np.sqrt(mses[i].detach().numpy())

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)/np.mean(mses)*100))
# Out:
# 23.11658 +- 21.024125814437866

# %% [markdown]
# Relu with N = 150

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 150)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "relu")

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 452.65323 +- 261.39362

# %% [markdown]
# Sigmoid with N = 50

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 50)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "sigmoid")

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
del out_mod
# Out:
# 563.2644 +- 371.98505

# %% [markdown]
# ## Varying hidden layer size

# %%
#2 neurons
out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 2)

a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for 2 hidden neurons')

plt.legend()

# %%
#5 neurons
out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 5)

a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for 5 hidden neurons')
plt.legend()

# %%
#10 neurons
out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 10)

a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for 10 hidden neurons')
plt.legend()

# %%
#10 neurons
out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 10)

a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(range(8500,10000), a[8500:10000], label = "Train")
plt.plot(range(8500,10000), b[8500:10000], label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for 10 hidden neurons')
plt.legend()

# %%
#20 Neurons
out_mod, loss,loss_valid,hist = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 20)

a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(a, label = "Train")
plt.plot(b, label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for 20 hidden neurons')
plt.legend()

# %%
out_mod_2, l,l,h = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 2)
out_mod_5, l,l,h = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 5)
out_mod_10, l,l,h = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 10)
out_mod_20, l,l,h = fed_sgd_nn(data, testing, iterations, N, S, n_feat, 20)

# %% [markdown]
# ### SWA Test

# %% [markdown]
# N = 150

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 150)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 10000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_swa(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "relu",
                                            swa_start = 8000)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 476.41116 +- 219.61748

# %%
a = [np.mean(loss[i]) for i in range(len(loss))]
b = [np.mean(loss_valid[i]) for i in range(len(loss))]
plt.plot(range(8500,10000), a[8500:10000], label = "Train")
plt.plot(range(8500,10000), b[8500:10000], label = "Validation")
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.title('Performence evolution for Fed SWA')
plt.legend()

# %% [markdown]
# N = 500

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 500)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_swa(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "relu",
                                            swa_start = 3000)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 435.77048 +- 180.1619

# %% [markdown]
# N = 50

# %%
data = []
test = []
df = [None]*len(dfs_big)


for i in range(len(dfs_big)):
    df[i] = dfs_big[i].sample(n = 50)
    X = df[i].loc[:, df[i].columns != 'pred']


    y = df[i].loc[:, df[i].columns == 'pred']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    
    mean_x_t = np.mean(X_train)
    std_x_t =  np.std(X_train)

    mean_y_t = np.mean(y_train)
    std_y_t =  np.std(y_train)

    X_train = (X_train-mean_x_t)/std_x_t
    y_train = (y_train-mean_y_t)/std_y_t

    X_test = (X_test-mean_x_t)/std_x_t
    y_test = (y_test-mean_y_t)/std_y_t
    
    data.append((X_train.to_numpy(),y_train.to_numpy()))
    test.append((X_test.to_numpy(),y_test.to_numpy()))

N = len(dfs_big)
iterations = 5000
S = 20
n_feat = 13
hidden_dim = 10

testing = [None]*len(test)

for i in range(len(data)): 
    x_i = torch.FloatTensor(data[i][0])
    y_i = torch.FloatTensor(data[i][1])
    x_t_i = torch.FloatTensor(test[i][0])
    y_t_i = torch.FloatTensor(test[i][1])
    data[i] = (x_i,y_i)
    testing[i] = (x_t_i,y_t_i)

out_mod, loss,loss_valid,hist = fed_sgd_swa(data, testing, iterations, N, S, n_feat, hidden_dim, activation = "relu",
                                            swa_start = 3000)

# %%
mses = []
loss_fn = nn.MSELoss()
for i in range(len(test)): 
    predictions = out_mod(torch.FloatTensor(test[i][0]))
    predictions = [x.detach().numpy()*std_y_t + mean_y_t for x in predictions]
    tests = [x*std_y_t + mean_y_t for x in test[i][1]]
    mses.append(loss_fn(torch.FloatTensor(predictions), torch.FloatTensor(tests)))



for i in range(len(mses)):
    mses[i] = mses[i].detach().numpy()

print(str(np.mean(mses)) + ' +- ' + str(np.std(mses)))
# Out:
# 556.36664 +- 270.35596

# %% [markdown]
# ## Fed SGD with non-linear Neural Network

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim,activation):
        super(NeuralNetwork, self).__init__()
        self.layer_1 = nn.Linear(input_dim, hidden_dim)
        self.activation = activation
        self.layer_2 = nn.Linear(hidden_dim, output_dim)
        
        
       
    def forward(self, x):
        if self.activation == "relu":
            x = torch.nn.functional.relu(self.layer_1(x))
        
        else :    
            x = torch.sigmoid(self.layer_1(x))
        
        x = self.layer_2(x)
        return x

    

def fed_sgd_nn(data, test, iterations, N, S, n_feat, hidden_dim, activation = "relu"):
    
    grad_mean_hist = [None]*iterations
    
    #Definition of the server model
    model_server = NeuralNetwork(n_feat, hidden_dim, 1, activation)
    optimizer_server = optim.Adam(model_server.parameters())
    loss_fn = nn.MSELoss()

    
    #One model per clients
    models = [None]*S
    opti = [None]*S
    loss_fct = [None]*S

    for i in range(len(models)):
        models[i] = NeuralNetwork(n_feat, hidden_dim, 1, activation)
        
        opti[i] = optim.Adam(models[i].parameters())
        loss_fct[i] = nn.MSELoss()

        
    mse = []
    mse_test = []
    #Iterations
    for i in range(0,iterations):


        
        #Random selection of clients
        a = list(range(0,N))
        sel = random.sample(a,S)
        
        
        grad_l1 = []
        bias_l1 = []
        
        
        grad_l2 = []
        bias_l2 = []
        
        loc = 0

        loss = [None]*S
        loss_test = [None]*S

        #Clients iteration
        for j in sel:
            #First layer
            
            models[loc].layer_1.weight = model_server.layer_1.weight
            
            #print(models[loc].layer_1.weight)
            models[loc].layer_1.weight.grad = None
            models[loc].layer_1.bias = model_server.layer_1.bias
            models[loc].layer_1.bias.grad = None
            
            opti[loc].zero_grad()
            
            #print(models[loc].layer_1.bias)
            
            #Second layer
            
            models[loc].layer_2.weight = model_server.layer_2.weight
            models[loc].layer_2.weight.grad = None
            models[loc].layer_2.bias = model_server.layer_2.bias
            models[loc].layer_2.bias.grad = None

            predictions = models[loc](data[j][0])
            
            predi_test = models[loc](test[j][0])
            

            
            loss[loc] = loss_fct[loc](predictions, data[j][1])
            loss_test[loc] = loss_fct[loc](predi_test, test[j][1])
            
            #print(loss[loc])
            
            loss[loc].backward(retain_graph = True)
            
            
            loss[loc] = loss[loc].item()
            loss_test[loc] = loss_test[loc].item()
            #print(models[loc].layer_1.weight.grad)

            grad_l1.append(models[loc].layer_1.weight.grad.numpy())
            bias_l1.append(models[loc].layer_1.bias.grad.numpy())
            

            
            grad_l2.append(models[loc].layer_2.weight.grad.numpy())
            bias_l2.append(models[loc].layer_2.bias.grad.numpy())
            
            loc+=1
        
        #print(grad_l1)
        mse.append((loss))
        mse_test.append((loss_test))
        grad_l1 = np.stack(grad_l1, axis=0)

        grad_l2 = np.stack(grad_l2, axis=0)
        
        grad_mean_l1 = torch.FloatTensor(grad_l1.mean(axis = 0))
        

        
        grad_mean_l2 = torch.FloatTensor(grad_l2.mean(axis = 0))
        #print(grad_mean_l1)
        grad_mean_hist[i] = grad_mean_l1
        #print("errr")
        #print(grad_mean_hist)
        
        bias_l1 = np.stack(bias_l1, axis = 0)
        bias_mean_l1 = torch.FloatTensor(bias_l1.mean(axis = 0))
        bias_mean_l2 = torch.FloatTensor([np.mean(bias_l2)])
        
        
        model_server.layer_1.weight.grad = grad_mean_l1
        #print(model_server.layer_1.weight.grad)
        model_server.layer_2.weight.grad = grad_mean_l2

        model_server.layer_1.bias.grad = bias_mean_l1
        model_server.layer_2.bias.grad = bias_mean_l2
        
        optimizer_server.step()
    return model_server, mse, mse_test, grad_mean_hist

# %% [markdown]
# ## Fed SGD SWA

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim,activation):
        super(NeuralNetwork, self).__init__()
        self.layer_1 = nn.Linear(input_dim, hidden_dim)
        self.activation = activation
        self.layer_2 = nn.Linear(hidden_dim, output_dim)
        
        
       
    def forward(self, x):
        if self.activation == "relu":
            x = torch.nn.functional.relu(self.layer_1(x))
        
        else :    
            x = torch.sigmoid(self.layer_1(x))
        
        x = self.layer_2(x)
        return x

    

def fed_sgd_swa(data, test, iterations, N, S, n_feat, hidden_dim, activation = "relu", swa_start = 3000):
    
    grad_mean_hist = [None]*iterations
    
    #Definition of the server model
    model_server = NeuralNetwork(n_feat, hidden_dim, 1, activation)
    optimizer_server = optim.Adam(model_server.parameters())
    loss_fn = nn.MSELoss()

    swa_model = torch.optim.swa_utils.AveragedModel(model_server)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer_server, T_max=300)
    swa_scheduler = SWALR(optimizer_server, swa_lr=0.05)
    
    #One model per clients
    models = [None]*S
    opti = [None]*S
    loss_fct = [None]*S

    for i in range(len(models)):
        models[i] = NeuralNetwork(n_feat, hidden_dim, 1, activation)
        
        opti[i] = optim.Adam(models[i].parameters())
        loss_fct[i] = nn.MSELoss()

        
    mse = []
    mse_test = []
    #Iterations
    for i in range(0,iterations):


        
        #Random selection of clients
        a = list(range(0,N))
        sel = random.sample(a,S)
        
        
        grad_l1 = []
        bias_l1 = []
        
        
        grad_l2 = []
        bias_l2 = []
        
        loc = 0

        loss = [None]*S
        loss_test = [None]*S

        #Clients iteration
        for j in sel:
            #First layer
            
            models[loc].layer_1.weight = model_server.layer_1.weight
            
            #print(models[loc].layer_1.weight)
            models[loc].layer_1.weight.grad = None
            models[loc].layer_1.bias = model_server.layer_1.bias
            models[loc].layer_1.bias.grad = None
            
            opti[loc].zero_grad()
            
            #print(models[loc].layer_1.bias)
            
            #Second layer
            
            models[loc].layer_2.weight = model_server.layer_2.weight
            models[loc].layer_2.weight.grad = None
            models[loc].layer_2.bias = model_server.layer_2.bias
            models[loc].layer_2.bias.grad = None

            predictions = models[loc](data[j][0])
            
            predi_test = models[loc](test[j][0])
            

            
            loss[loc] = loss_fct[loc](predictions, data[j][1])
            loss_test[loc] = loss_fct[loc](predi_test, test[j][1])
            
            #print(loss[loc])
            
            loss[loc].backward(retain_graph = True)
            
            
            loss[loc] = loss[loc].item()
            loss_test[loc] = loss_test[loc].item()
            #print(models[loc].layer_1.weight.grad)

            grad_l1.append(models[loc].layer_1.weight.grad.numpy())
            bias_l1.append(models[loc].layer_1.bias.grad.numpy())
            

            
            grad_l2.append(models[loc].layer_2.weight.grad.numpy())
            bias_l2.append(models[loc].layer_2.bias.grad.numpy())
            
            loc+=1
        
        #print(grad_l1)
        mse.append((loss))
        mse_test.append((loss_test))
        grad_l1 = np.stack(grad_l1, axis=0)

        grad_l2 = np.stack(grad_l2, axis=0)
        
        grad_mean_l1 = torch.FloatTensor(grad_l1.mean(axis = 0))
        

        
        grad_mean_l2 = torch.FloatTensor(grad_l2.mean(axis = 0))
        #print(grad_mean_l1)
        grad_mean_hist[i] = grad_mean_l1
        #print("errr")
        #print(grad_mean_hist)
        
        bias_l1 = np.stack(bias_l1, axis = 0)
        bias_mean_l1 = torch.FloatTensor(bias_l1.mean(axis = 0))
        bias_mean_l2 = torch.FloatTensor([np.mean(bias_l2)])
        
        
        model_server.layer_1.weight.grad = grad_mean_l1
        #print(model_server.layer_1.weight.grad)
        model_server.layer_2.weight.grad = grad_mean_l2

        model_server.layer_1.bias.grad = bias_mean_l1
        model_server.layer_2.bias.grad = bias_mean_l2
        
        optimizer_server.step()
        
                
        if i > swa_start:
            swa_model.update_parameters(model_server)
            swa_scheduler.step()
        
    return model_server, mse, mse_test, grad_mean_hist
